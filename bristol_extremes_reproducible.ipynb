# %% [markdown]
# # Bristol 5.1.0 — offline reproduction
# Download the daily JSON and the companion Python script into this directory. Results use complete years only. These are exploratory statistics, not flood forecasts.

# %%
# %run bristol_extremes_reproducible.py bristol-climate-daily.json
