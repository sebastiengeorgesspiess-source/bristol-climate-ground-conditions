# %% [markdown]
# # Bristol 5.1 — raw monthly export
# Download the companion bristol_climate_analysis.py and bristol-climate.json. This helper exports raw overlapping months only. It does not reproduce the interactive baseline, lag or uncertainty calculations. Use the dashboard CSV for those settings.

# %%
# %run bristol_climate_analysis.py bristol-climate.json --a swep_rain_mm:value --b frome_monthly_flow_m3s:value --out comparison.csv
